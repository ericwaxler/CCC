# %%
import pandas as pd
import numpy as np
import requests
import json
import calendar
import time
import re
from dateutil.parser import parse
import matplotlib.pyplot as plt
import decimal
import sklearn

import boto3
import base64
from botocore.exceptions import ClientError

# %%
df = pd.read_csv('consolidated_coin_data.csv')
df.head()
# Out:
#   Currency       Date      Open      High       Low     Close         Volume  \
# 0   ripple  24-Apr-19  0.321114  0.321282  0.296982  0.302318  1,517,791,002
# 1   ripple  23-Apr-19  0.323844  0.328396  0.320919  0.321222  1,077,333,990
# 2   ripple  22-Apr-19  0.322277   0.32935  0.320237  0.323934  1,131,094,080
# 3   ripple  21-Apr-19  0.328678  0.329627  0.318746  0.322449  1,005,803,846
# 4   ripple  20-Apr-19  0.331871  0.333213  0.324969  0.328476    931,570,799
#
#        Market Cap
# 0  12,698,877,293
# 1  13,492,933,875
# 2  13,606,823,301
# 3  13,533,407,430
# 4  13,786,384,592

# %%
df['Currency'].value_counts()
# Out:
# litecoin        2305
# bitcoin         2305
# ripple          2207
# stellar         1841
# tether          1632
# ethereum        1484
# eos              780
# bitcoin-cash     758
# binance-coin     756
# cardano          688
# Name: Currency, dtype: int64

# %%
df.loc[df['Currency'] == 'bitcoin']
# Out:
#       Currency          Date           Open           High            Low  \
# 3392   bitcoin     24-Apr-19        5571.51        5642.04        5418.26
# 3393   bitcoin     23-Apr-19        5399.37         5633.8        5389.41
# 3394   bitcoin     22-Apr-19        5312.49        5422.69        5280.28
# 3395   bitcoin     21-Apr-19        5335.88        5359.93        5257.34
# 3396   bitcoin     20-Apr-19        5304.16        5358.49        5295.88
# 3397   bitcoin     19-Apr-19        5298.15        5336.68        5233.34
# 3398   bitcoin     18-Apr-19        5251.48        5319.99        5250.51
# 3399   bitcoin     17-Apr-19        5236.14        5274.28        5219.21
# 3400   bitcoin     16-Apr-19        5066.58        5238.95        5055.19
# 3401   bitcoin     15-Apr-19        5167.32        5196.61        5024.07
# 3402   bitcoin     14-Apr-19        5095.76        5184.02        5053.57
# 3403   bitcoin     13-Apr-19        5088.85        5127.12        5061.59
# 3404   bitcoin     12-Apr-19         5061.2        5103.27        4955.85
# 3405   bitcoin     11-Apr-19        5325.08        5354.23         5017.3
# 3406   bitcoin     10-Apr-19        5204.11        5421.65        5193.38
# 3407   bitcoin      9-Apr-19        5289.92        5289.92        5167.42
# 3408   bitcoin      8-Apr-19        5199.84        5318.84        5148.21
# 3409   bitcoin      7-Apr-19        5062.79        5235.19        5050.41
# 3410   bitcoin      6-Apr-19        5036.79        5205.82        4992.22
# 3411   bitcoin      5-Apr-19        4922.81        5053.51        4919.49
# 3412   bitcoin      4-Apr-19        4971.31        5063.16        4836.79
# 3413   bitcoin      3-Apr-19        4879.96           5307        4876.62
# 3414   bitcoin      2-Apr-19        4156.92        4905.95        4155.32
# 3415   bitcoin      1-Apr-19        4105.36        4164.95         4096.9
# 3416   bitcoin     31-Mar-19        4105.46        4113.02         4094.1
# 3417   bitcoin     30-Mar-19        4092.14        4296.81        4053.91
# 3418   bitcoin     29-Mar-19         4068.3         4113.5         4034.1
# 3419   bitcoin     28-Mar-19        4087.58         4094.9        4040.27
# 3420   bitcoin     27-Mar-19        3984.24        4087.07        3977.81
# 3421   bitcoin     26-Mar-19        3969.23        3985.08        3944.75
# ...        ...           ...            ...            ...            ...
# 13663  bitcoin     14-May-19       7,807.88       8,268.71       7,696.39
# 13664  bitcoin     13-May-19       6,971.18       8,047.41       6,898.28
# 13665  bitcoin     12-May-19       7,203.51       7,503.87       6,815.77
# 13666  bitcoin     11-May-19       6,379.67       7,333.00       6,375.70
# 13667  bitcoin     10-May-19       6,175.82       6,434.62       6,161.52
# 13668  bitcoin      9-May-19       5,982.32       6,183.04       5,982.32
# 13669  bitcoin      8-May-19       5,849.48       5,989.98       5,794.72
# 13670  bitcoin      7-May-19       5,745.60       5,988.18       5,741.40
# 13671  bitcoin      6-May-19       5,791.69       5,802.96       5,653.69
# 13672  bitcoin      5-May-19       5,831.07       5,833.86       5,708.04
# 13673  bitcoin      4-May-19       5,769.20       5,886.89       5,645.47
# 13674  bitcoin      3-May-19       5,505.55       5,865.88       5,490.20
# 13675  bitcoin      2-May-19       5,402.42       5,522.26       5,394.22
# 13676  bitcoin      1-May-19       5,350.91       5,418.00       5,347.65
# 13677  bitcoin     30-Apr-19       5,247.73       5,363.26       5,224.19
# 13678  bitcoin     29-Apr-19       5,284.86       5,311.27       5,216.49
# 13679  bitcoin     28-Apr-19       5,271.75       5,326.23       5,255.68
# 13680  bitcoin     27-Apr-19       5,279.47       5,310.75       5,233.64
# 13681  bitcoin     26-Apr-19       5,210.30       5,383.63       5,177.37
# 13682  bitcoin     25-Apr-19       5,466.52       5,542.24       5,181.34
# 14656  bitcoin  Aug 17, 2019  10358.7225407  10452.6246924  10086.6979603
# 14657  bitcoin  Aug 16, 2019  10319.4203458  10524.3498284  9855.47883007
# 14658  bitcoin  Aug 15, 2019  10038.4217089  10437.4106507   9675.3164202
# 14659  bitcoin  Aug 14, 2019  10889.4877427  10889.5569207  10028.1353635
# 14660  bitcoin  Aug 13, 2019  11385.0524972  11420.0498609  10830.3269144
# 14661  bitcoin  Aug 12, 2019  11528.1893667  11528.1893667  11320.9515001
# 14662  bitcoin  Aug 11, 2019  11349.7398943  11523.5793784  11248.2948234
# 14663  bitcoin  Aug 10, 2019  11861.5566954  11915.6552603  11323.8987573
# 14664  bitcoin  Aug 09, 2019  11953.4695395  11970.4577149  11709.7453788
# 14665  bitcoin  Aug 08, 2019  11954.0403364  11979.4201746  11556.1684508
#
#                Close          Volume         Market Cap
# 3392         5464.87  17,048,033,399     96,530,038,144
# 3393         5572.36  15,867,308,108     98,417,387,004
# 3394         5399.37  14,601,631,648     95,354,207,776
# 3395         5314.53  13,731,844,223     93,847,052,256
# 3396         5337.89  13,169,647,522     94,248,717,444
# 3397         5303.81  13,780,238,655     93,638,345,002
# 3398         5298.39  13,256,489,918     93,532,402,741
# 3399         5251.94  12,438,480,677     92,702,617,458
# 3400         5235.56  11,618,660,197     92,404,613,297
# 3401         5067.11  12,290,155,061     89,422,237,603
# 3402         5167.72  10,391,952,498     91,188,595,341
# 3403         5096.59  10,823,289,598     89,925,574,875
# 3404         5089.54  13,675,206,312     89,792,633,045
# 3405         5064.49  16,555,616,019     89,341,168,457
# 3406         5324.55  15,504,590,933     93,918,439,274
# 3407         5204.96  14,722,104,361     91,799,330,425
# 3408         5289.77  17,154,113,634     93,286,365,973
# 3409          5198.9  16,655,416,140     91,674,230,186
# 3410         5059.82  16,929,795,194     89,212,733,450
# 3411         5036.68  16,837,325,387     88,796,118,650
# 3412          4922.8  18,251,810,240     86,778,727,821
# 3413         4973.02  22,899,891,582     87,655,288,145
# 3414         4879.88  21,315,047,816     85,986,009,273
# 3415         4158.18  10,157,794,171     73,269,368,747
# 3416          4105.4   9,045,122,443     72,339,379,036
# 3417         4106.66   9,732,688,060     72,355,190,645
# 3418         4098.37  10,918,665,557     72,202,088,875
# 3419         4069.11   9,353,915,899     71,678,998,915
# 3420         4087.07  10,897,131,934     71,987,847,571
# 3421         3985.08  10,707,678,815     70,184,147,203
# ...              ...             ...                ...
# 13663       7,994.42  32,031,452,227    141,508,656,735
# 13664       7,814.92  28,677,672,182    138,316,573,807
# 13665       6,972.37  27,773,333,680    123,389,710,222
# 13666       7,204.77  28,867,562,329    127,488,435,181
# 13667       6,378.85  19,419,875,368    112,863,284,035
# 13668       6,174.53  16,784,645,411    109,238,600,750
# 13669       5,982.46  15,320,605,300    105,829,143,585
# 13670       5,829.50  18,026,409,033    103,112,368,557
# 13671       5,746.81  15,737,171,804    101,640,471,056
# 13672       5,795.71  14,808,830,723    102,494,420,158
# 13673       5,831.17  17,567,780,766    103,112,021,259
# 13674       5,768.29  18,720,780,006    101,986,240,859
# 13675       5,505.28  14,644,460,907     97,330,112,147
# 13676       5,402.70  13,679,528,237     95,501,110,091
# 13677       5,350.73  13,878,964,574     94,573,826,828
# 13678       5,247.35  13,735,490,672     92,737,510,865
# 13679       5,285.14  12,819,992,056     93,391,244,395
# 13680       5,268.29  13,111,274,675     93,086,156,556
# 13681       5,279.35  16,812,108,040     93,272,287,960
# 13682       5,210.52  15,330,283,408     92,046,492,864
# 14656  10231.7438454   13778035685.0  1.82966857173e+11
# 14657  10374.3393471   20228207096.4  1.85500055339e+11
# 14658   10311.545429   22899115082.1  1.84357666577e+11
# 14659  10051.7039313   19990838299.9  1.79692803424e+11
# 14660  10895.8304358   16681503537.0  1.94762696644e+11
# 14661  11382.6159562   13647198229.0  2.03441494985e+11
# 14662  11523.5793784   15774371518.0  2.05941632235e+11
# 14663  11354.0242177   18125355447.0  2.02890020455e+11
# 14664    11862.93676   18339989959.5  2.11961319133e+11
# 14665   11966.407405   19481591729.5  2.13788089212e+11
#
# [2305 rows x 8 columns]

# %%
df['UnixDate'] = ""
df['UnixDate'] = df['Date'].apply(lambda x : calendar.timegm(time.strptime(parse(x).date().strftime("%m-%d-%Y"), '%m-%d-%Y')))
df['Date'] = df['Date'].apply(lambda x : parse(x).date().strftime("%m-%d-%Y"))
df['Open'] = df['Open'].apply(lambda x : float(x.replace(',','')))
df['High'] = df['High'].apply(lambda x : float(x.replace(',','')))
df['Close'] = df['Close'].apply(lambda x : float(x.replace(',','')))
df['Low'] = df['Low'].apply(lambda x : float(x.replace(',','')))
df.head()
# Out:
#   Currency        Date      Open      High       Low     Close         Volume  \
# 0   ripple  04-24-2019  0.321114  0.321282  0.296982  0.302318  1,517,791,002
# 1   ripple  04-23-2019  0.323844  0.328396  0.320919  0.321222  1,077,333,990
# 2   ripple  04-22-2019  0.322277  0.329350  0.320237  0.323934  1,131,094,080
# 3   ripple  04-21-2019  0.328678  0.329627  0.318746  0.322449  1,005,803,846
# 4   ripple  04-20-2019  0.331871  0.333213  0.324969  0.328476    931,570,799
#
#        Market Cap    UnixDate
# 0  12,698,877,293  1556064000
# 1  13,492,933,875  1555977600
# 2  13,606,823,301  1555891200
# 3  13,533,407,430  1555804800
# 4  13,786,384,592  1555718400

# %%
df.groupby(df['Currency'])['Date'].min().sort_values()
# Out:
# Currency
# bitcoin         01-01-2014
# litecoin        01-01-2014
# ripple          01-01-2014
# stellar         01-01-2015
# ethereum        01-01-2016
# tether          01-01-2016
# binance-coin    01-01-2018
# bitcoin-cash    01-01-2018
# cardano         01-01-2018
# eos             01-01-2018
# Name: Date, dtype: object

# %%
df_focus = df.loc[df['Currency'].isin(['ethereum','ripple','litecoin','bitcoin','stellar','cardano'])]
df_focus = df_focus.loc[df_focus['UnixDate'] > 1438905600]
df_focus.head()
# Out:
#   Currency        Date      Open      High       Low     Close         Volume  \
# 0   ripple  04-24-2019  0.321114  0.321282  0.296982  0.302318  1,517,791,002
# 1   ripple  04-23-2019  0.323844  0.328396  0.320919  0.321222  1,077,333,990
# 2   ripple  04-22-2019  0.322277  0.329350  0.320237  0.323934  1,131,094,080
# 3   ripple  04-21-2019  0.328678  0.329627  0.318746  0.322449  1,005,803,846
# 4   ripple  04-20-2019  0.331871  0.333213  0.324969  0.328476    931,570,799
#
#        Market Cap    UnixDate
# 0  12,698,877,293  1556064000
# 1  13,492,933,875  1555977600
# 2  13,606,823,301  1555891200
# 3  13,533,407,430  1555804800
# 4  13,786,384,592  1555718400

# %%
df_focus['Currency'].value_counts()
# Out:
# ethereum    1483
# litecoin    1473
# ripple      1473
# stellar     1473
# bitcoin     1473
# cardano      688
# Name: Currency, dtype: int64

# %%
df_pivot = pd.pivot_table(df_focus, index=['UnixDate'], values='Close',columns='Currency',aggfunc='first')
df_pivot.count()
# Out:
# Currency
# bitcoin     1471
# cardano      686
# ethereum    1471
# litecoin    1471
# ripple      1471
# stellar     1471
# dtype: int64

# %%
df_pivot.sort_values(by='UnixDate',ascending=False).head(5)
# Out:
# Currency         bitcoin   cardano    ethereum   litecoin    ripple   stellar
# UnixDate
# 1566000000  10231.743845  0.047393  185.687679  72.797722  0.265721  0.067888
# 1565913600  10374.339347  0.046841  185.440073  74.920154  0.261971  0.068921
# 1565827200  10311.545429  0.047519  188.502060  76.388978  0.264882  0.070261
# 1565740800  10051.703931  0.047000  186.607741  76.064986  0.263343  0.069183
# 1565654400  10895.830436  0.052561  208.709041  84.406144  0.296639  0.074162

# %%
df_rec = df_pivot.loc[df_pivot.index.get_level_values(level = 'UnixDate') >= 1510832000] 
df_rec.head()
# Out:
# Currency    bitcoin   cardano  ethereum  litecoin    ripple   stellar
# UnixDate
# 1510876800  7708.99  0.025773    332.39     67.57  0.226581  0.035572
# 1510963200  7790.15  0.026369    347.61     69.64  0.228627  0.036583
# 1511049600  8036.49  0.028084    354.39     71.59  0.231016  0.036566
# 1511136000  8200.64  0.029581    366.73     72.25  0.238759  0.038121
# 1511222400  8071.26  0.028330    360.40     70.03  0.233271  0.037668

# %%
from sklearn import preprocessing
x = df_rec.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)

df_norm = pd.DataFrame(x_scaled)
df_norm.columns = df_rec.columns
df_norm.index = df_rec.index
df_norm.head()
# Out:
# Currency     bitcoin   cardano  ethereum  litecoin    ripple   stellar
# UnixDate
# 1510876800  0.275034  0.000000  0.189070  0.131719  0.001190  0.000000
# 1510963200  0.280025  0.000550  0.200669  0.137900  0.001838  0.001175
# 1511049600  0.295175  0.002131  0.205836  0.143723  0.002595  0.001155
# 1511136000  0.305270  0.003512  0.215241  0.145694  0.005048  0.002962
# 1511222400  0.297313  0.002358  0.210417  0.139065  0.003309  0.002435

# %%
plt.figure()
df_norm.plot(figsize=(19,4))

# %%
plt.figure()
df_norm[['bitcoin','ethereum']].plot(figsize=(19,4))

# %%
df_ml = pd.DataFrame(data={'bitcoin':df_norm['bitcoin'].values,'ethereum':df_norm['ethereum'].values,'litecoin':df_norm['litecoin'].values,'ripple':df_norm['ripple'].values},index=df_norm.index)

# %%
df_ml.head()
# Out:
#              bitcoin  ethereum  litecoin    ripple
# UnixDate
# 1510876800  0.284325  0.187245  0.139989  0.000361
# 1510963200  0.274696  0.188623  0.130932  0.000928
# 1511049600  0.278934  0.200366  0.137188  0.001436
# 1511136000  0.295747  0.205460  0.142849  0.002455
# 1511222400  0.306011  0.215626  0.145202  0.004573

# %%
X = df_ml[['ripple','litecoin','ethereum']]
y = df_ml['bitcoin']

# %%
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(X):
    #print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
plt.plot(X_train)
plt.plot(X_test)
plt.show()

# %%
plt.plot(y_train)
plt.plot(y_test)
plt.show()

# %% [markdown]
# # LSTM

# %%
X_train = np.reshape(X_train.to_numpy(), (X_train.to_numpy().shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test.to_numpy(), (X_test.to_numpy().shape[0], 1, X_test.shape[1]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

model2 = Sequential()
model2.add(layers.LSTM(20, input_shape=(1, 3), return_sequences=True))
model2.add(layers.LSTM(20))
model2.add(layers.Dense(1, activation='relu'))
model2.compile(optimizer="adam", loss="mean_squared_error")
model2.fit(X_train, y_train, epochs=75, verbose=0)

# %%
model2.evaluate(X_test, y_test)
# Out:
# 106/106 [==============================] - 1s 11ms/sample - loss: 0.0342
# 0.0342203732931389

# %%
m2predictions = model2.predict(X_test)
zipped2 = list(zip(m2predictions,y_test))

# %%
plt.plot(zipped2)
# Out:
# [<matplotlib.lines.Line2D at 0x1a341c3c88>,
#  <matplotlib.lines.Line2D at 0x1a341c3dd8>]

# %%
df_focus.loc[df_focus['Currency'] == 'bitcoin'].sort_values(by='UnixDate',ascending=True, axis=0).reset_index().sort_index(ascending=True, axis=0).head(10)
# Out:
#    index Currency        Date    Open    High     Low   Close      Volume  \
# 0   4747  bitcoin  08-08-2015  279.74  279.93  260.71  261.00  58,533,000
# 1   4746  bitcoin  08-09-2015  261.12  267.00  260.47  265.08  23,789,600
# 2   4745  bitcoin  08-10-2015  265.48  267.03  262.60  264.47  20,979,400
# 3   4744  bitcoin  08-11-2015  264.34  270.39  264.09  270.39  25,433,900
# 4   4743  bitcoin  08-12-2015  270.60  270.67  265.47  266.38  26,815,400
# 5   4742  bitcoin  08-13-2015  266.18  266.23  262.84  264.08  27,685,500
# 6   4741  bitcoin  08-14-2015  264.13  267.47  261.48  265.68  27,091,200
# 7   4740  bitcoin  08-15-2015  265.53  266.67  261.30  261.55  19,321,100
# 8   4739  bitcoin  08-16-2015  261.87  262.44  257.04  258.51  29,717,000
# 9   4738  bitcoin  08-17-2015  258.49  260.51  257.12  257.98  21,617,900
#
#       Market Cap    UnixDate
# 0  3,778,049,024  1438992000
# 1  3,838,130,130  1439078400
# 2  3,830,352,069  1439164800
# 3  3,917,142,819  1439251200
# 4  3,859,888,131  1439337600
# 5  3,827,588,724  1439424000
# 6  3,851,715,726  1439510400
# 7  3,792,757,590  1439596800
# 8  3,749,501,856  1439683200
# 9  3,742,748,055  1439769600

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

#creating dataframe
df = df_focus.loc[df_focus['Currency'] == 'bitcoin'].sort_values(by='UnixDate',ascending=True, axis=0).reset_index()

data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]
# Out:
# Using TensorFlow backend.

# %%
#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

train = dataset[0:1247,:]
valid = dataset[1247:,:]

#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(30,len(train)):
    x_train.append(scaled_data[i-30:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
plt.plot(new_data)

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# create and fit the LSTM network
model4 = Sequential()
model4.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model4.add(LSTM(units=50))
model4.add(Dense(1))

model4.compile(loss='mean_squared_error', optimizer='adam')
model4.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)

#predicting 246 values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 30:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(30,inputs.shape[0]):
    X_test.append(inputs[i-30:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model4.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# Train on 1217 samples
# 1217/1217 - 26s - loss: 0.0025

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
# Out:
# 536.4081563950273

# %%
train = new_data[:1247]
valid = new_data[1247:]
valid['Predictions'] = closing_price

plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [<matplotlib.lines.Line2D at 0x1a3693efd0>,
#  <matplotlib.lines.Line2D at 0x1a36a3fcf8>]

# %%
plt.plot(valid[['Close','Predictions']])
# Out:
# [<matplotlib.lines.Line2D at 0x1a37aa07b8>,
#  <matplotlib.lines.Line2D at 0x1a3771fc50>]

# %%
plt.figure(figsize=(24,7))
plt.plot(valid[['Close','Predictions']].tail(21))
plt.legend(['Predicted','Actual'])

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
#from keras.models import Sequential
#from keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

#creating dataframe
df = df_focus.loc[df_focus['Currency'] == 'ethereum'].sort_values(by='UnixDate',ascending=True, axis=0).reset_index()

data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]
#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

train = dataset[0:1247,:]
valid = dataset[1247:,:]

#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(30,len(train)):
    x_train.append(scaled_data[i-30:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# create and fit the LSTM network
model4 = Sequential()
model4.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model4.add(LSTM(units=50))
model4.add(Dense(1))

model4.compile(loss='mean_squared_error', optimizer='adam')
model4.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)

#predicting 246 values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 30:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(30,inputs.shape[0]):
    X_test.append(inputs[i-30:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model4.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
# Out:
# Train on 1217 samples
# 1217/1217 - 28s - loss: 0.0029

# %%
train = new_data[:1247]
valid = new_data[1247:]
valid['Predictions'] = closing_price

#plt.plot(train['Close'])
plt.figure(figsize=(24,7))
plt.plot(valid[['Close','Predictions']])
plt.legend(['Actual','Predicted'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(24,7))
plt.plot(valid[['Close','Predictions']].tail(21))
plt.legend(['Actual','Predicted'])
